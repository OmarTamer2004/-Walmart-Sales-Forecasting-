# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/features.csv')

# %%
df
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05        42.31       2.572        NaN        NaN
# 1         1  2010-02-12        38.51       2.548        NaN        NaN
# 2         1  2010-02-19        39.93       2.514        NaN        NaN
# 3         1  2010-02-26        46.63       2.561        NaN        NaN
# 4         1  2010-03-05        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0           NaN        NaN        NaN  211.096358         8.106      False
# 1           NaN        NaN        NaN  211.242170         8.106       True
# 2           NaN        NaN        NaN  211.289143         8.106      False
# 3           NaN        NaN        NaN  211.319643         8.106      False
# 4           NaN        NaN        NaN  211.350143         8.106      False
# ...         ...        ...        ...         ...           ...        ...
# 8185       3.00    2449.97    3169.69         NaN           NaN      False
# 8186     582.74    5797.47    1514.93         NaN           NaN      False
# 8187      85.72     744.84    2150.36         NaN           NaN      False
# 8188     204.19     363.00    1059.46         NaN           NaN      False
# 8189       2.06      10.88    1864.57         NaN           NaN      False
#
# [8190 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB

# %%
df.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
stores=pd.read_csv('/content/stores.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB

# %%
stores
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# 39     40    A  155083
# 40     41    A  196321
# 41     42    C   39690
# 42     43    C   41062
# 43     44    C   39910
# 44     45    B  118221

# %%
train=pd.read_csv('/content/train.csv')
# Out:
# /tmp/ipython-input-3461219278.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   train=pd.read_csv('/content/train.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB

# %%
train
# Out:
#         Store  Dept        Date  Weekly_Sales IsHoliday
# 0           1     1  2010-02-05      24924.50     False
# 1           1     1  2010-02-12      46039.49      True
# 2           1     1  2010-02-19      41595.55     False
# 3           1     1  2010-02-26      19403.54     False
# 4           1     1  2010-03-05      21827.90     False
# ...       ...   ...         ...           ...       ...
# 241333     25    32  2011-10-14       3298.56     FALSE
# 241334     25    32  2011-10-21       3297.56     FALSE
# 241335     25    32  2011-10-28       2965.97     FALSE
# 241336     25    32  2011-11-04       2524.38     FALSE
# 241337     25    32  2011-11-11       3377.43       FAL
#
# [241338 rows x 5 columns]

# %%
train=pd.read_csv('/content/train.csv')
# Out:
# /tmp/ipython-input-3461219278.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   train=pd.read_csv('/content/train.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB

# %%
train
# Out:
#         Store  Dept        Date  Weekly_Sales IsHoliday
# 0           1     1  2010-02-05      24924.50     False
# 1           1     1  2010-02-12      46039.49      True
# 2           1     1  2010-02-19      41595.55     False
# 3           1     1  2010-02-26      19403.54     False
# 4           1     1  2010-03-05      21827.90     False
# ...       ...   ...         ...           ...       ...
# 309674     32    44  2012-08-24       4533.20     False
# 309675     32    44  2012-08-31       3767.29     False
# 309676     32    44  2012-09-07       4152.52      True
# 309677     32    44  2012-09-14       4394.31     False
# 309678     32    44  2012-09-21         42.00       NaN
#
# [309679 rows x 5 columns]

# %%
df.drop(['MarkDown1','MarkDown2','MarkDown3','MarkDown4','MarkDown5'],axis =1 , inplace = True )

# %%
df
# Out:
#       Store        Date  Temperature  Fuel_Price         CPI  Unemployment  \
# 0         1  2010-02-05        42.31       2.572  211.096358         8.106
# 1         1  2010-02-12        38.51       2.548  211.242170         8.106
# 2         1  2010-02-19        39.93       2.514  211.289143         8.106
# 3         1  2010-02-26        46.63       2.561  211.319643         8.106
# 4         1  2010-03-05        46.50       2.625  211.350143         8.106
# ...     ...         ...          ...         ...         ...           ...
# 8185     45  2013-06-28        76.05       3.639         NaN           NaN
# 8186     45  2013-07-05        77.50       3.614         NaN           NaN
# 8187     45  2013-07-12        79.37       3.614         NaN           NaN
# 8188     45  2013-07-19        82.84       3.737         NaN           NaN
# 8189     45  2013-07-26        76.06       3.804         NaN           NaN
#
#       IsHoliday
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
# ...         ...
# 8185      False
# 8186      False
# 8187      False
# 8188      False
# 8189      False
#
# [8190 rows x 7 columns]

# %%
merged_df = df.merge(stores, on='Store', how='left')
merged_df
# Out:
#       Store        Date  Temperature  Fuel_Price         CPI  Unemployment  \
# 0         1  2010-02-05        42.31       2.572  211.096358         8.106
# 1         1  2010-02-12        38.51       2.548  211.242170         8.106
# 2         1  2010-02-19        39.93       2.514  211.289143         8.106
# 3         1  2010-02-26        46.63       2.561  211.319643         8.106
# 4         1  2010-03-05        46.50       2.625  211.350143         8.106
# ...     ...         ...          ...         ...         ...           ...
# 8185     45  2013-06-28        76.05       3.639         NaN           NaN
# 8186     45  2013-07-05        77.50       3.614         NaN           NaN
# 8187     45  2013-07-12        79.37       3.614         NaN           NaN
# 8188     45  2013-07-19        82.84       3.737         NaN           NaN
# 8189     45  2013-07-26        76.06       3.804         NaN           NaN
#
#       IsHoliday Type    Size
# 0         False    A  151315
# 1          True    A  151315
# 2         False    A  151315
# 3         False    A  151315
# 4         False    A  151315
# ...         ...  ...     ...
# 8185      False    B  118221
# 8186      False    B  118221
# 8187      False    B  118221
# 8188      False    B  118221
# 8189      False    B  118221
#
# [8190 rows x 9 columns]

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   CPI           7605 non-null   float64
#  5   Unemployment  7605 non-null   float64
#  6   IsHoliday     8190 non-null   bool
#  7   Type          8190 non-null   object
#  8   Size          8190 non-null   int64
# dtypes: bool(1), float64(4), int64(2), object(2)
# memory usage: 520.0+ KB

# %%
train_merged = train.merge(merged_df, on=['Store', 'Date', 'IsHoliday'], how='left')

# %%
df=train_merged

# %%
df
# Out:
#         Store  Dept        Date  Weekly_Sales IsHoliday  Temperature  \
# 0           1     1  2010-02-05      24924.50     False        42.31
# 1           1     1  2010-02-12      46039.49      True        38.51
# 2           1     1  2010-02-19      41595.55     False        39.93
# 3           1     1  2010-02-26      19403.54     False        46.63
# 4           1     1  2010-03-05      21827.90     False        46.50
# ...       ...   ...         ...           ...       ...          ...
# 309674     32    44  2012-08-24       4533.20     False        70.12
# 309675     32    44  2012-08-31       3767.29     False        76.12
# 309676     32    44  2012-09-07       4152.52      True        72.56
# 309677     32    44  2012-09-14       4394.31     False        64.05
# 309678     32    44  2012-09-21         42.00       NaN          NaN
#
#         Fuel_Price         CPI  Unemployment Type      Size
# 0            2.572  211.096358         8.106    A  151315.0
# 1            2.548  211.242170         8.106    A  151315.0
# 2            2.514  211.289143         8.106    A  151315.0
# 3            2.561  211.319643         8.106    A  151315.0
# 4            2.625  211.350143         8.106    A  151315.0
# ...            ...         ...           ...  ...       ...
# 309674       3.558  198.098420         7.872    A  203007.0
# 309675       3.556  198.096734         7.872    A  203007.0
# 309676       3.596  198.095048         7.872    A  203007.0
# 309677       3.659  198.126718         7.872    A  203007.0
# 309678         NaN         NaN           NaN  NaN       NaN
#
# [309679 rows x 11 columns]

# %%
df['IsHoliday'] = df['IsHoliday'].map({True: 1, False: 0})

# %%
df['Type'].value_counts()
# Out:
# Type
# A    158192
# B    144330
# C      7156
# Name: count, dtype: int64

# %%
df['Type'] = df['Type'].map({'A': 1, 'B': 2,'C' :3})

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df. isna().sum()
# Out:
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday       1
# Temperature     1
# Fuel_Price      1
# CPI             1
# Unemployment    1
# Type            1
# Size            1
# dtype: int64

# %%
df.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 0      1     1 2010-02-05      24924.50        0.0        42.31       2.572
# 1      1     1 2010-02-12      46039.49        1.0        38.51       2.548
# 2      1     1 2010-02-19      41595.55        0.0        39.93       2.514
# 3      1     1 2010-02-26      19403.54        0.0        46.63       2.561
# 4      1     1 2010-03-05      21827.90        0.0        46.50       2.625
#
#           CPI  Unemployment  Type      Size
# 0  211.096358         8.106   1.0  151315.0
# 1  211.242170         8.106   1.0  151315.0
# 2  211.289143         8.106   1.0  151315.0
# 3  211.319643         8.106   1.0  151315.0
# 4  211.350143         8.106   1.0  151315.0

# %%
df['day']=df.Date.dt.day

# %%
df['month']=df.Date.dt.month

# %%
df['year']=df.Date.dt.year

# %%
df.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 0      1     1 2010-02-05      24924.50        0.0        42.31       2.572
# 1      1     1 2010-02-12      46039.49        1.0        38.51       2.548
# 2      1     1 2010-02-19      41595.55        0.0        39.93       2.514
# 3      1     1 2010-02-26      19403.54        0.0        46.63       2.561
# 4      1     1 2010-03-05      21827.90        0.0        46.50       2.625
#
#           CPI  Unemployment  Type      Size  day  month  year
# 0  211.096358         8.106   1.0  151315.0    5      2  2010
# 1  211.242170         8.106   1.0  151315.0   12      2  2010
# 2  211.289143         8.106   1.0  151315.0   19      2  2010
# 3  211.319643         8.106   1.0  151315.0   26      2  2010
# 4  211.350143         8.106   1.0  151315.0    5      3  2010

# %%
df.set_index(df['Date'],inplace=True)

# %%
df.drop( 'Date',axis=1 , inplace =True)

# %%
df.head()
# Out:
#             Store  Dept  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# Date
# 2010-02-05      1     1      24924.50        0.0        42.31       2.572
# 2010-02-12      1     1      46039.49        1.0        38.51       2.548
# 2010-02-19      1     1      41595.55        0.0        39.93       2.514
# 2010-02-26      1     1      19403.54        0.0        46.63       2.561
# 2010-03-05      1     1      21827.90        0.0        46.50       2.625
#
#                    CPI  Unemployment  Type      Size  day  month  year
# Date
# 2010-02-05  211.096358         8.106   1.0  151315.0    5      2  2010
# 2010-02-12  211.242170         8.106   1.0  151315.0   12      2  2010
# 2010-02-19  211.289143         8.106   1.0  151315.0   19      2  2010
# 2010-02-26  211.319643         8.106   1.0  151315.0   26      2  2010
# 2010-03-05  211.350143         8.106   1.0  151315.0    5      3  2010

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 309679 entries, 2010-02-05 to 2012-09-21
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         309679 non-null  int64
#  1   Dept          309679 non-null  int64
#  2   Weekly_Sales  309679 non-null  float64
#  3   IsHoliday     309678 non-null  float64
#  4   Temperature   309678 non-null  float64
#  5   Fuel_Price    309678 non-null  float64
#  6   CPI           309678 non-null  float64
#  7   Unemployment  309678 non-null  float64
#  8   Type          309678 non-null  float64
#  9   Size          309678 non-null  float64
#  10  day           309679 non-null  int32
#  11  month         309679 non-null  int32
#  12  year          309679 non-null  int32
# dtypes: float64(8), int32(3), int64(2)
# memory usage: 29.5 MB

# %%
df.describe().T
# Out:
#                  count           mean           std        min            25%  \
# Store         309679.0      16.219340      9.071128      1.000       8.000000
# Dept          309679.0      43.414981     29.839534      1.000      19.000000
# Weekly_Sales  309679.0   17140.600746  23941.832113  -4988.940    2661.720000
# IsHoliday     309678.0       0.070451      0.255905      0.000       0.000000
# Temperature   309678.0      59.459035     18.523543     -2.060      46.140000
# Fuel_Price    309678.0       3.364272      0.459236      2.514       2.935000
# CPI           309678.0     173.003839     39.767230    126.064     132.751667
# Unemployment  309678.0       7.825794      1.807200      3.879       6.833000
# Type          309678.0       1.512280      0.544119      1.000       1.000000
# Size          309678.0  147676.206879  56279.060214  34875.000  114533.000000
# day           309679.0      15.672606      8.753302      1.000       8.000000
# month         309679.0       6.447056      3.244705      1.000       4.000000
# year          309679.0    2010.966843      0.796865   2010.000    2010.000000
#
#                       50%            75%            max
# Store             16.0000      24.000000      32.000000
# Dept              36.0000      71.000000      99.000000
# Weekly_Sales    8337.4900   21601.720000  693099.360000
# IsHoliday          0.0000       0.000000       1.000000
# Temperature       61.3500      73.520000      99.220000
# Fuel_Price         3.4520       3.742000       4.468000
# CPI              185.7545     214.488691     227.232807
# Unemployment       7.7710       8.324000      14.313000
# Type               1.0000       2.000000       3.000000
# Size          151315.0000  203750.000000  219622.000000
# day               16.0000      23.000000      31.000000
# month              6.0000       9.000000      12.000000
# year            2011.0000    2012.000000    2012.000000

# %%
import matplotlib.pyplot as plt
df['Weekly_Sales'].plot(kind='box')
# Out:
# <Axes: >

# %%
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

outliers = {}

for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Get rows where outliers exist
    outlier_rows = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    outliers[col] = {
        "Total Outliers": outlier_rows.shape[0],
        "Percentage": round(100 * outlier_rows.shape[0] / df.shape[0], 2)
    }


pd.DataFrame(outliers).T.sort_values(by="Total Outliers", ascending=False)
# Out:
#               Total Outliers  Percentage
# Unemployment         26369.0        8.51
# Weekly_Sales         26231.0        8.47
# IsHoliday            21817.0        7.05
# Temperature             69.0        0.02
# Dept                     0.0        0.00
# Store                    0.0        0.00
# Fuel_Price               0.0        0.00
# CPI                      0.0        0.00
# Type                     0.0        0.00
# Size                     0.0        0.00

# %%
Q1 = df['Weekly_Sales'].quantile(0.25)
Q3 = df['Weekly_Sales'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df = df[(df['Weekly_Sales'] >= lower) & (df['Weekly_Sales'] <= upper)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 283448 entries, 2010-02-05 to 2012-09-21
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         283448 non-null  int64
#  1   Dept          283448 non-null  int64
#  2   Weekly_Sales  283448 non-null  float64
#  3   IsHoliday     283447 non-null  float64
#  4   Temperature   283447 non-null  float64
#  5   Fuel_Price    283447 non-null  float64
#  6   CPI           283447 non-null  float64
#  7   Unemployment  283447 non-null  float64
#  8   Type          283447 non-null  float64
#  9   Size          283447 non-null  float64
#  10  day           283448 non-null  int32
#  11  month         283448 non-null  int32
#  12  year          283448 non-null  int32
# dtypes: float64(8), int32(3), int64(2)
# memory usage: 27.0 MB

# %%
x=df.drop('Weekly_Sales',axis=1)
y=df['Weekly_Sales']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.4 ,random_state=42)

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')

x_train = imputer.fit_transform(x_train)
x_test = imputer.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

models = {
    'LinearRegression': LinearRegression(),
    'XGBoost': XGBRegressor(n_estimators=100, verbosity=0),
}

for name, model in models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    mse = mean_squared_error(y_test, y_pred)
    print(f'{name} - MSE: {mse:.2f}')
# Out:
# LinearRegression - MSE: 132155782.02
# XGBoost - MSE: 10025676.14

# %%
from sklearn.preprocessing import MinMaxScaler

scaler_X = MinMaxScaler()
X_train_scaled= scaler_X.fit_transform(x_train)
X_test_scaled = scaler_X.transform(x_test)

scaler_y = MinMaxScaler()
y_train_scaled = scaler_y.fit_transform(y_train.to_numpy().reshape(-1, 1))
y_test_scaled = scaler_y.transform(y_test.to_numpy().reshape(-1, 1))

# %%
for name, model in models.items():
    model.fit(X_train_scaled, y_train_scaled)
    y_pred = model.predict(X_test_scaled)
    mse = mean_squared_error(y_test_scaled, y_pred)
    print(f'{name} - MSE: {mse:.2f}')
# Out:
# LinearRegression - MSE: 0.04
# XGBoost - MSE: 0.00

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test_scaled, y_pred)
print(f'{name} - R2 Score: {r2:.2f}')
# Out:
# XGBoost - R2 Score: 0.93

# %%
y_pred_scaled = model.predict(X_test_scaled)

y_pred = scaler_y.inverse_transform(y_pred_scaled.reshape(-1, 1)).ravel()
y_test_actual = scaler_y.inverse_transform(y_test_scaled).ravel()

import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(y_test_actual[:200], label='True Values')
plt.plot(y_pred[:200], label='Predicted Values', alpha=0.7)
plt.title('True vs Predicted Sales (first 200 samples)')
plt.xlabel('Sample Index')
plt.ylabel('Sales')
plt.legend()
plt.grid()
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense , Input

Dmodel = Sequential([
    Dense(16,activation = 'relu', input_dim=12),
    Dense(8,activation = 'relu',),
    Dense(8,activation = 'relu'),
    Dense(1,activation = 'linear')
                    ]


)

Dmodel.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
Dmodel.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 425 (1.66 KB)
#  Trainable params: 425 (1.66 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history=Dmodel.fit(X_train_scaled,y_train_scaled,epochs=30, validation_split=0.2)
# Out:
# Epoch 1/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - loss: 0.0469 - mae: 0.1662 - val_loss: 0.0350 - val_mae: 0.1391
# Epoch 2/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 19s 6ms/step - loss: 0.0358 - mae: 0.1395 - val_loss: 0.0345 - val_mae: 0.1359
# Epoch 3/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.0353 - mae: 0.1380 - val_loss: 0.0349 - val_mae: 0.1324
# Epoch 4/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0347 - mae: 0.1362 - val_loss: 0.0338 - val_mae: 0.1360
# Epoch 5/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0347 - mae: 0.1358 - val_loss: 0.0336 - val_mae: 0.1345
# Epoch 6/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0343 - mae: 0.1351 - val_loss: 0.0332 - val_mae: 0.1353
# Epoch 7/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0336 - mae: 0.1332 - val_loss: 0.0333 - val_mae: 0.1347
# Epoch 8/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0337 - mae: 0.1333 - val_loss: 0.0331 - val_mae: 0.1316
# Epoch 9/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0334 - mae: 0.1323 - val_loss: 0.0327 - val_mae: 0.1290
# Epoch 10/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0333 - mae: 0.1319 - val_loss: 0.0324 - val_mae: 0.1319
# Epoch 11/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0331 - mae: 0.1317 - val_loss: 0.0329 - val_mae: 0.1368
# Epoch 12/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0332 - mae: 0.1318 - val_loss: 0.0325 - val_mae: 0.1333
# Epoch 13/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0327 - mae: 0.1309 - val_loss: 0.0322 - val_mae: 0.1313
# Epoch 14/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0325 - mae: 0.1304 - val_loss: 0.0328 - val_mae: 0.1365
# Epoch 15/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0325 - mae: 0.1306 - val_loss: 0.0321 - val_mae: 0.1339
# Epoch 16/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0324 - mae: 0.1304 - val_loss: 0.0317 - val_mae: 0.1280
# Epoch 17/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0326 - mae: 0.1302 - val_loss: 0.0321 - val_mae: 0.1322
# Epoch 18/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0322 - mae: 0.1299 - val_loss: 0.0314 - val_mae: 0.1282
# Epoch 19/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0319 - mae: 0.1288 - val_loss: 0.0316 - val_mae: 0.1264
# Epoch 20/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0318 - mae: 0.1288 - val_loss: 0.0316 - val_mae: 0.1307
# Epoch 21/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0322 - mae: 0.1296 - val_loss: 0.0316 - val_mae: 0.1263
# Epoch 22/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.0320 - mae: 0.1290 - val_loss: 0.0317 - val_mae: 0.1282
# Epoch 23/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0317 - mae: 0.1284 - val_loss: 0.0311 - val_mae: 0.1271
# Epoch 24/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0315 - mae: 0.1285 - val_loss: 0.0310 - val_mae: 0.1274
# Epoch 25/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0320 - mae: 0.1294 - val_loss: 0.0312 - val_mae: 0.1260
# Epoch 26/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0320 - mae: 0.1290 - val_loss: 0.0318 - val_mae: 0.1334
# Epoch 27/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.0318 - mae: 0.1289 - val_loss: 0.0308 - val_mae: 0.1284
# Epoch 28/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0314 - mae: 0.1276 - val_loss: 0.0310 - val_mae: 0.1274
# Epoch 29/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - loss: 0.0313 - mae: 0.1273 - val_loss: 0.0310 - val_mae: 0.1291
# Epoch 30/30
# 2835/2835 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0310 - mae: 0.1269 - val_loss: 0.0309 - val_mae: 0.1292

# %%
Dmodel.evaluate(X_test_scaled,y_test_scaled)
# Out:
# 5315/5315 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 0.0312 - mae: 0.1294
# [0.031167790293693542, 0.129355326294899]
